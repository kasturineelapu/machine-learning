# %%
#required libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
#import matplotlib.pyplot as plt

# %%
startups = pd.read_csv("50_Startups.csv")
startups.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#Import the library
#Import the data
#Data analysis, manupulations
#Splitting the data like testing and training(80,20)
#Apply the algoritm
#Evolution

# %%
# R&D vs Profit

plt.scatter(startups["R&D Spend"],startups["Profit"], color ="g")
plt.xlabel("R&D Spend")
plt.ylabel("Profit")
plt.legend(["R&D vs Profit"])

# %%
#Administration vs Profit 
plt.scatter(startups["Administration"],startups["Profit"], color ="g")
plt.xlabel("Administration")
plt.ylabel("Profit")
plt.legend(["Administration vs Profit"])

# %%
#Marketing Spend vs 
plt.scatter(startups["Marketing Spend"],startups["Profit"], color ="g")
plt.xlabel("Marketing Spend")
plt.ylabel("Profit")
plt.legend(["Marketing Spend vs Profit"])

# %%
#data seperation based on dependent and independent variables
#x=startups["R&D Spend"]
#y=startups["Profit"]
x= startups.iloc[:,0].values  
y= startups.iloc[:,4].values
# Out:
# array([165349.2 , 162597.7 , 153441.51, 144372.41, 142107.34, 131876.9 ,
#        134615.46, 130298.13, 120542.52, 123334.88, 101913.08, 100671.96,
#         93863.75,  91992.39, 119943.24, 114523.61,  78013.11,  94657.16,
#         91749.16,  86419.7 ,  76253.86,  78389.47,  73994.56,  67532.53,
#         77044.01,  64664.71,  75328.87,  72107.6 ,  66051.52,  65605.48,
#         61994.48,  61136.38,  63408.86,  55493.95,  46426.07,  46014.02,
#         28663.76,  44069.95,  20229.59,  38558.51,  28754.33,  27892.92,
#         23640.93,  15505.73,  22177.74,   1000.23,   1315.46,      0.  ,
#           542.05,      0.  ])

# %%
#Split the data for Testing and training
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
startups_reg = LinearRegression()

# %%
y_train = y_train.reshape(-1, 1)

# %%
startups_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = startups_reg.predict(x_test)

# %%
y_test
# Out:
# array([134307.35,  81005.76,  99937.59,  64926.08, 125370.37,  35673.41,
#        105733.54, 107404.34,  97427.84, 122776.86])

# %%
y_pred
# Out:
# array([[127862.20996405],
#        [ 82250.56334619],
#        [102255.72078164],
#        [ 50190.4734756 ],
#        [130136.88190548],
#        [ 49799.36685472],
#        [113638.0775288 ],
#        [104535.0534288 ],
#        [103463.04843113],
#        [123105.31102669]])

# %%
plt.scatter(x_test, y_test, color="green")   
plt.scatter(x_test, y_pred, color="red")
